# %%
pip install datasets
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import datasets
data = datasets.load_dataset("ccdv/patent-classification")
data
# Out:
# ...
# No config specified, defaulting to: patent-classification/patent
# ...
# Dataset patent-classification downloaded and prepared to /Users/yenaahn/.cache/huggingface/datasets/ccdv___patent-classification/patent/1.0.0/36f060b0495318e9e707de169384a47de1b16c1b7379afee0807fbcc759f8786. Subsequent calls will reuse this data.
# 100%|██████████| 3/3 [00:00<00:00, 52.73it/s]
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'label'],
#         num_rows: 25000
#     })
#     validation: Dataset({
#         features: ['text', 'label'],
#         num_rows: 5000
#     })
#     test: Dataset({
#         features: ['text', 'label'],
#         num_rows: 5000
#     })
# })

# %%
import pandas as pd
import numpy as np

# %%
train = pd.DataFrame(data['train'])
test = pd.DataFrame(data['test'])
valid = pd.DataFrame(data['validation'])
display(train,test,valid)
# Out:
#                                                     text  label
# 0      turning now to the drawings , there is shown i...      6
# 1      deployment mechanisms that are configured for ...      0
# 2      now , first and second embodiments of the pres...      7
# 3      as used herein , “ administration ” of a compo...      0
# 4      in accordance with the figures , the mixing de...      8
# ...                                                  ...    ...
# 24995  referring now to fig1 , 2 and 3 , a tag body 2...      6
# 24996  in the following , the embodiments of the pres...      6
# 24997  for the manipulation of dna , standard methods...      2
# 24998  the fan blade technology disclosed in u . s . ...      5
# 24999  fig1 is a perspective view of a first form a -...      0
#
# [25000 rows x 2 columns]
#                                                    text  label
# 0     as used herein , the term &# 34 ; sensitizer m...      8
# ...

# %%
all_data = pd.concat([train, test, valid])
all_data = all_data.iloc[:,:-1]
all_data
# Out:
#                                                sentence  label
# 0     Our friends won't buy this analysis, let alone...      1
# 1     One more pseudo generalization and I'm giving up.      1
# 2      One more pseudo generalization or I'm giving up.      1
# 3        The more we study verbs, the crazier they get.      1
# 4             Day by day the facts are getting murkier.      1
# ...                                                 ...    ...
# 1038                         John considers Bill silly.      1
# 1039                   John considers Bill to be silly.      1
# 1040        John bought a dog for himself to play with.      0
# 1041        John arranged for himself to get the prize.      1
# 1042                 John talked to Bill about himself.      1
#
# [10657 rows x 2 columns]

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
tk = Tokenizer()
tk.fit_on_texts([all_data['sentence']])
print(tk.word_index)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/sj/kc9zmrwd11lcxvfqmcz6qjk40000gn/T/ipykernel_1217/2999740623.py in <module>
#       1 from tensorflow.keras.preprocessing.text import Tokenizer
#       2 tk = Tokenizer()
# ----> 3 tk.fit_on_texts([all_data['sentence']])
#       4 print(tk.word_index)
#
# /opt/anaconda3/envs/tf/lib/python3.7/site-packages/keras_preprocessing/text.py in fit_on_texts(self, texts)
#     223                                             self.filters,
#     224                                             self.lower,
# --> 225                                             self.split)
#     226             for w in seq:
#     227                 if w in self.word_counts:
#
# /opt/anaconda3/envs/tf/lib/python3.7/site-packages/keras_preprocessing/text.py in text_to_word_sequence(text, filters, lower, split)
#      41     """
# ...
